# %%
import pandas as pd
df_csv = pd.read_csv('../data/people.csv')
df_csv
# Out:
#      name  age       city
# 0    Aman   25      Delhi
# 1  Bhavna   30     Mumbai
# 2  Chetan   22       Pune
# 3   Divya   28  Bangalore

# %%
df_csv.head(3)
# Out:
#      name  age    city
# 0    Aman   25   Delhi
# 1  Bhavna   30  Mumbai
# 2  Chetan   22    Pune

# %%
df_csv.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
len(df_csv)
# Out:
# 4

# %%
df_csv['age'].max()
# Out:
# np.int64(30)

# %%
df_csv[df_csv['age']>25]
# Out:
#      name  age       city
# 1  Bhavna   30     Mumbai
# 3   Divya   28  Bangalore

# %%
df_csv[df_csv['city']=='Delhi']
# Out:
#    name  age   city
# 0  Aman   25  Delhi

# %%
df_csv[(df_csv['age']>23) & (df_csv['city'].isin(['Mumbai','Pune']) )]
# Out:
#      name  age    city
# 1  Bhavna   30  Mumbai

# %%
df_csv['age_2_years_later']=df_csv['age']+2
df_csv
# Out:
#      name  age       city  age_2_years_later
# 0    Aman   25      Delhi                 27
# 1  Bhavna   30     Mumbai                 32
# 2  Chetan   22       Pune                 24
# 3   Divya   28  Bangalore                 30

# %%
df_csv['name_length']=df_csv['name'].str.len()
df_csv
# Out:
#      name  age       city  age_2_years_later  name_length
# 0    Aman   25      Delhi                 27            4
# 1  Bhavna   30     Mumbai                 32            6
# 2  Chetan   22       Pune                 24            6
# 3   Divya   28  Bangalore                 30            5

# %%
df_csv.groupby('city')['age'].mean()
# Out:
# city
# Bangalore    28.0
# Delhi        25.0
# Mumbai       30.0
# Pune         22.0
# Name: age, dtype: float64

# %%
df_csv.groupby('city')['name'].count()
# Out:
# city
# Bangalore    1
# Delhi        1
# Mumbai       1
# Pune         1
# Name: name, dtype: int64
